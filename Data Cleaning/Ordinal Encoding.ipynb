# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'Size': ['s', 'm', 'l', 'xl', 's', 'm', 'l', 's', 's', 'l', 'xl', 'm']})
df.head(3)
# Out:
#   Size
# 0    s
# 1    m
# 2    l

# %%
ord_data=[['s','m','l','xl']]

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe=OrdinalEncoder() # creates an empty OrdinalEncoder object from sklearn.

# %%
oe
# Out:
# OrdinalEncoder()

# %%
# Initialize encoder with this order
oe = OrdinalEncoder(categories=ord_data)

# Fit encoder on your column
oe.fit(df[['Size']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 5
#       2 oe = OrdinalEncoder(categories=ord_data)
#       4 # Fit encoder on your column
# ----> 5 oe.fit(df[['Size']])
#
# File C:\anacondaa\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File C:\anacondaa\Lib\site-packages\sklearn\preprocessing\_encoders.py:1515, in OrdinalEncoder.fit(self, X, y)
#    1508     raise TypeError(
#    1509         "unknown_value should only be set when "
#    1510         "handle_unknown is 'use_encoded_value', "
# ...

# %%
oe.transform() #Transforming your original 'Size' column into numeric codes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 oe.transform()
#
# TypeError: OrdinalEncoder.transform() missing 1 required positional argument: 'X'

# %%
df
# Out:
#     Size
# 0    0.0
# 1    1.0
# 2    2.0
# 3    3.0
# 4    0.0
# 5    1.0
# 6    2.0
# 7    0.0
# 8    0.0
# 9    2.0
# 10   3.0
# 11   1.0
