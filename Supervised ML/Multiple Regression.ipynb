# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r'Multipleregression.csv')

# %%
dataset.head(3)
# Out:
#    Age  Salary  Experience
# 0   15   10000           2
# 1   20   20000           3
# 2   25   25000           1

# %%
dataset.shape
# Out:
# (10, 3)

# %%
dataset.isnull().sum()
# Out:
# Age           0
# Salary        0
# Experience    0
# dtype: int64

# %%
sns.pairplot(data=dataset)
plt.show()

# %%
sns.heatmap(data=dataset.corr(),annot=True)
plt.show()

# %%
x=dataset.iloc[:,:-1]
x
# Out:
#    Age  Salary
# 0   15   10000
# 1   20   20000
# 2   25   25000
# 3   30   30000
# 4   35   35000
# 5   40   40000
# 6   45   45000
# 7   50   50000
# 8   55   55000
# 9   60   60000

# %%
x=dataset.iloc[:,:-1]
y=dataset['Experience']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 14.64660037624298

# %%
lr.coef_
# Out:
# array([-0.12786885,  0.00014426])

# %%
lr.intercept_
# Out:
# np.float64(2.4754098360655714)

# %%
lr.predict(x_test)
# Out:
# array([3.37704918, 2.80327869])
